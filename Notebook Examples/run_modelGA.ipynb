# %%
import json 
from netCDF4 import Dataset
import numpy as np
from scipy.spatial.distance import pdist
import random
from sklearn.model_selection import train_test_split
import NeuralNetwork
from GeneticAlgorithm import GeneticAlgorithm

import math 
with open('configGA.json') as f:
  print(f)
  config = json.loads(f.read())
import random

print(config)
# Out:
# <_io.TextIOWrapper name='configGA.json' mode='r' encoding='UTF-8'>
# {'config': {'debug': 'on', 'database': {'file': 'db.dat', 'properties': ['energy', 'gradient'], 'crdmode': 'cartesian', 'timestamp': '2021-04-23T18:25:43.511Z', 'mode': 'ab-initio', 'ab-initio': {'exe': 'QChem.exe', 'chg': 0, 'mult': 1, 'exchange': 'pbe0', 'basis': 'cc-pvdz', 'max_scf_cycles': 500, 'xc_grid': '000075000302', 'mem_static': 4000, 'mem_total': 16000, 'sym_ignore': True, 'set_iter': 50, 'input_bohr': True}}, 'neural_network': {'epochs': 200, 'epoch_step': 50, 'logging_file': 'logfile.txt', 'plotting_file': 'plottingfile.txt', 'optimizer': 'adam', 'activation': 'tanh', 'loss_function': 'MSE', 'model_filename': 'Network.pt'}, 'genetic_algorithm': {'hiddenlayer_size': [10, 200, 10], 'validation_ratio': 0.1, 'hiddenlayer_number': [1, 20, 1], 'learning_rates': [1, 0.1, 0.01, 0.001, 0.0001], 'batch_size': [32, 64, 128, 256, 512], 'mutation_rate': 0.1, 'iterations': 2000, 'population_size': 6}}}

# %%
lowest_error, best_network = math.inf, None
sizebounds = config['config']['genetic_algorithm']['hiddenlayer_size']
layerbounds = config['config']['genetic_algorithm']['hiddenlayer_number']
learningbounds = config['config']['genetic_algorithm']['learning_rates']


print(random.randint(sizebounds[0],sizebounds[1]))
print(random.choice(learningbounds))

#for n in range(self.config['config']['simulated_annealing']['iterations']) :
# Out:
# 70
# 0.1

# %%
database = 'db.dat'
data = Dataset(database, mode='r')
if config['config']["database"]["crdmode"] == "cartesian":
    dbset = np.copy(data['crd'])
    coordinatesout = []
    for j,i in enumerate(dbset):
        if j == 0:
            coordinatesout = [pdist(i)]
        else:
            coordinatesout = np.concatenate((coordinatesout,[pdist(i)]))
            
energyout =np.copy(data['energy'])-np.amin(data['energy'])     
print(coordinatesout)
print(energyout)
# Out:
# [[2.77941757 2.76440917 4.84697076]
#  [2.76698152 2.76900611 4.83948085]
#  [2.75691651 2.77593716 4.83429377]
#  [2.74938863 2.78508657 4.83143719]
#  [2.74453164 2.79630852 4.83089482]
#  [2.74244372 2.80942972 4.83260669]
#  [2.7431851  2.82425238 4.83647096]
#  [2.74677709 2.8405571  4.84234703]
#  [2.75320254 2.85810566 4.8500602 ]
#  [2.76240746 2.87664359 4.85940741]
#  [2.77430386 2.89590254 4.87016427]]
# [[1.30026000e-05 1.38476884e-01 1.58162384e-01]
#  [0.00000000e+00 1.39150584e-01 1.58955644e-01]
#  [2.89870001e-05 1.39480344e-01 1.59147334e-01]
#  [8.40001001e-05 1.39443554e-01 1.58714964e-01]
#  [1.63652300e-04 1.39037264e-01 1.57668304e-01]
#  [2.81846500e-04 1.38279024e-01 1.56049534e-01]
#  [4.67269800e-04 1.37206234e-01 1.53931434e-01]
#  [7.61541000e-04 1.35874014e-01 1.51413464e-01]
#  [1.21603860e-03 1.34351604e-01 1.48616114e-01]
#  [1.88761530e-03 1.32717424e-01 1.45673914e-01]
#  [2.83360780e-03 1.31053354e-01 1.42727624e-01]]

# %%
coordinates, val_coordinates, output, val_output = train_test_split(coordinatesout, energyout , test_size=config['config']['genetic_algorithm']['validation_ratio'])

print(output,val_output)
print(coordinates, val_coordinates)
# Out:
# [[2.89870001e-05 1.39480344e-01 1.59147334e-01]
#  [1.21603860e-03 1.34351604e-01 1.48616114e-01]
#  [2.81846500e-04 1.38279024e-01 1.56049534e-01]
#  [1.88761530e-03 1.32717424e-01 1.45673914e-01]
#  [8.40001001e-05 1.39443554e-01 1.58714964e-01]
#  [2.83360780e-03 1.31053354e-01 1.42727624e-01]
#  [1.63652300e-04 1.39037264e-01 1.57668304e-01]
#  [0.00000000e+00 1.39150584e-01 1.58955644e-01]
#  [1.30026000e-05 1.38476884e-01 1.58162384e-01]] [[0.00046727 0.13720623 0.15393143]
#  [0.00076154 0.13587401 0.15141346]]
# [[2.75691651 2.77593716 4.83429377]
#  [2.75320254 2.85810566 4.8500602 ]
#  [2.74244372 2.80942972 4.83260669]
#  [2.76240746 2.87664359 4.85940741]
#  [2.74938863 2.78508657 4.83143719]
#  [2.77430386 2.89590254 4.87016427]
#  [2.74453164 2.79630852 4.83089482]
#  [2.76698152 2.76900611 4.83948085]
#  [2.77941757 2.76440917 4.84697076]] [[2.7431851  2.82425238 4.83647096]
#  [2.74677709 2.8405571  4.84234703]]

# %%
#if (any(i == 'simulated_annealing' for i in config['config'])):
#    if (any(j == 'neural_network' for j in config['config'])):
#        optimizer = SimulatedAnnealing(config,coordinates,  output,val_coordinates, val_output)
#        optimizer.run()

if (any(i == 'genetic_algorithm' for i in config['config'])):
    if (any(j == 'neural_network' for j in config['config'])):
        optimizer = GeneticAlgorithm(config,coordinates,  output,val_coordinates, val_output)
        optimizer.run()
# Out:
# Current population is: [[2, 11, 1, 1], [5, 1, 0, 1], [3, 16, 2, 0], [6, 1, 2, 1], [12, 15, 3, 1], [11, 16, 1, 3]]
# 0.19678432870520834 0 30 12 0.1
# 0.07254150050499064 50 30 12 0.1
# 0.00664617296484971 100 30 12 0.1
# 0.0011143148940565054 150 30 12 0.1
# Done Training
# 13.183386974695164 0 60 2 1
# 1.345569977235142 50 60 2 1
# 0.11091194424113236 100 60 2 1
# 0.009143291527056494 150 60 2 1
# Done Training
# 0.10077089267717504 0 40 17 0.01
# 0.0017814004961579383 50 40 17 0.01
# 0.0011048752693948324 100 40 17 0.01
# 0.0011351563098284973 150 40 17 0.01
# Done Training
# 0.7222730069532517 0 70 2 0.01
# 0.0179123236776411 50 70 2 0.01
# 0.0007788525772617956 100 70 2 0.01
# 0.0019656883862705587 150 70 2 0.01
# Done Training
# 0.05656460846878589 0 130 16 0.001
# 0.0010492796368135535 50 130 16 0.001
# 0.0010948414717570356 100 130 16 0.001
# 0.0011381316888103752 150 130 16 0.001
# Done Training
# 3.4057557213349114 0 120 17 0.1
# 0.2576788832271136 50 120 17 0.1
# 0.019249334019393997 100 120 17 0.1
# 0.0016799269655981604 150 120 17 0.1
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['01100'] and ['00110']
# these are bitwise: ['01100', '00111'] and ['00110', '01001']
# these are bitwise: ['01100', '00111', '11'] and ['00110', '01001', '10']
# these are bitwise: ['01100', '00111', '11', '01'] and ['00110', '01001', '10', '01']
# Current population is: [[6, 1, 2, 1], [12, 15, 3, 1], [3, 16, 2, 0], [2, 11, 1, 1], [13, 7, 3, 1], [17, 17, 2, 1]]
# library
# library
# library
# library
# 0.08975273002401915 0 140 8 0.001
# 0.002621316265161362 50 140 8 0.001
# 0.001265787770587843 100 140 8 0.001
# 0.0011109715984934634 150 140 8 0.001
# Done Training
# 0.4924593628715994 0 180 18 0.01
# 0.024196795030388126 50 180 18 0.01
# 0.002686984175163212 100 180 18 0.01
# 0.0011601814672036826 150 180 18 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00110'] and ['01100']
# these are bitwise: ['00110', '00011'] and ['01100', '01101']
# these are bitwise: ['00110', '00011', '11'] and ['01100', '01101', '10']
# these are bitwise: ['00110', '00011', '11', '01'] and ['01100', '01101', '10', '01']
# Current population is: [[6, 1, 2, 1], [12, 15, 3, 1], [3, 16, 2, 0], [13, 7, 3, 1], [6, 3, 3, 1], [17, 5, 2, 1]]
# library
# library
# library
# library
# 0.09494509519419168 0 70 4 0.001
# 0.0037382906149719787 50 70 4 0.001
# 0.0012860182525073734 100 70 4 0.001
# 0.001075517781704354 150 70 4 0.001
# Done Training
# 0.4301211317967819 0 180 6 0.01
# 0.048451680090300285 50 180 6 0.01
# 0.0018498158932346205 100 180 6 0.01
# 0.0012828727055070922 150 180 6 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['01110']
# these are bitwise: ['00100', '00011'] and ['01110', '01101']
# these are bitwise: ['00100', '00011', '11'] and ['01110', '01101', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['01110', '01101', '10', '01']
# Current population is: [[6, 1, 2, 1], [12, 15, 3, 1], [6, 3, 3, 1], [3, 16, 2, 0], [4, 3, 3, 3], [14, 13, 2, 1]]
# library
# library
# library
# library
# 0.021449603175295987 0 50 4 0.001
# 0.0017071485490396752 50 50 4 0.001
# 0.0009697143046783413 100 50 4 0.001
# 0.0008011183431263814 150 50 4 0.001
# Done Training
# 0.6519180440209958 0 150 14 0.01
# 0.01786909832467466 50 150 14 0.01
# 0.020908361142029687 100 150 14 0.01
# 0.0028234630067935926 150 150 14 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00001'] and ['00110', '00011']
# these are bitwise: ['00100', '00001', '11'] and ['00110', '00011', '10']
# these are bitwise: ['00100', '00001', '11', '01'] and ['00110', '00011', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [12, 15, 3, 1], [6, 3, 3, 1], [4, 17, 3, 1], [6, 3, 2, 3]]
# library
# library
# library
# library
# 0.03694734650917905 0 50 18 0.001
# 0.0026043861985697034 50 50 18 0.001
# 0.0011056726357738214 100 50 18 0.001
# 0.0011341884100278766 150 50 18 0.001
# Done Training
# 0.38919676220549126 0 70 4 0.01
# 0.00257028597008474 50 70 4 0.01
# 0.0010684899696968505 100 70 4 0.01
# 0.018321673091387908 150 70 4 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [12, 15, 3, 1], [6, 3, 2, 3], [0, 3, 1, 1], [6, 17, 1, 3]]
# library
# library
# library
# library
# 0.5123245663241274 0 10 4 0.1
# 0.01661589497411796 50 10 4 0.1
# 0.001824534424057493 100 10 4 0.1
# 0.0011441546804595905 150 10 4 0.1
# Done Training
# 1.6127889491395786 0 70 18 0.1
# 0.1021427307077065 50 70 18 0.1
# 0.005868367315463426 100 70 18 0.1
# 0.0013252442361376814 150 70 18 0.1
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [12, 15, 3, 1], [6, 3, 2, 3], [0, 3, 2, 1], [14, 1, 2, 1]]
# library
# library
# library
# library
# 0.22333167263104034 0 10 4 0.01
# 0.006876032625820123 50 10 4 0.01
# 0.001377654044501144 100 10 4 0.01
# 0.0009890653498983942 150 10 4 0.01
# Done Training
# 1.2477393283408602 0 150 2 0.01
# 0.017801091205770735 50 150 2 0.01
# 0.003461771350904571 100 150 2 0.01
# 0.0011393569364993874 150 150 2 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [0, 3, 2, 1], [12, 15, 3, 1], [12, 1, 3, 1], [6, 1, 2, 2]]
# library
# library
# library
# library
# 0.08667207859517859 0 130 2 0.001
# 0.0012087420123628866 50 130 2 0.001
# 0.0011365328092997461 100 130 2 0.001
# 0.00131776267605116 150 130 2 0.001
# Done Training
# 1.0324206224892654 0 70 2 0.01
# 0.019452145089602104 50 70 2 0.01
# 0.0013255599524941819 100 70 2 0.01
# 0.0009551522373447656 150 70 2 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [6, 1, 2, 2], [0, 3, 2, 1], [4, 17, 3, 1], [14, 5, 2, 3]]
# library
# library
# library
# library
# library
# 0.35534162339519043 0 150 6 0.01
# 0.04399191618897652 50 150 6 0.01
# 0.022034257051545346 100 150 6 0.01
# 0.0009839229171484307 150 150 6 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [6, 1, 2, 2], [14, 5, 2, 3], [4, 11, 2, 1], [6, 1, 0, 3]]
# library
# library
# library
# library
# 0.16474829746431038 0 50 12 0.01
# 0.0026256177214345686 50 50 12 0.01
# 0.001191285234346214 100 50 12 0.01
# 0.0011288890380060262 150 50 12 0.01
# Done Training
# 11.096122461673396 0 70 2 1
# 2.322725858745363 50 70 2 1
# 0.10731568963731031 100 70 2 1
# 0.011150611872261624 150 70 2 1
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00001'] and ['00110', '00011']
# these are bitwise: ['00100', '00001', '11'] and ['00110', '00011', '10']
# these are bitwise: ['00100', '00001', '11', '01'] and ['00110', '00011', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [6, 1, 2, 2], [14, 5, 2, 3], [4, 1, 3, 1], [6, 1, 2, 3]]
# library
# library
# library
# library
# 0.16056905081040845 0 50 2 0.001
# 0.009788505186675981 50 50 2 0.001
# 0.001024651055608177 100 50 2 0.001
# 0.001007721884609466 150 50 2 0.001
# Done Training
# 0.7226227932050681 0 70 2 0.01
# 0.013104949306897882 50 70 2 0.01
# 0.007937486994002475 100 70 2 0.01
# 0.001167378710138981 150 70 2 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [6, 1, 2, 2], [14, 5, 2, 3], [12, 7, 3, 1], [6, 1, 2, 3]]
# library
# library
# library
# library
# 0.023790682379258087 0 130 8 0.001
# 0.0009136542937108785 50 130 8 0.001
# 0.0010708119905246316 100 130 8 0.001
# 0.001087199043254314 150 130 8 0.001
# Done Training
# library
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00110'] and ['00100']
# these are bitwise: ['00110', '00011'] and ['00100', '00001']
# these are bitwise: ['00110', '00011', '11'] and ['00100', '00001', '10']
# these are bitwise: ['00110', '00011', '11', '01'] and ['00100', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [12, 7, 3, 1], [6, 1, 2, 2], [6, 3, 3, 1], [4, 1, 2, 3]]
# library
# library
# library
# library
# library
# 0.45527428037537876 0 50 2 0.01
# 0.006366203996643855 50 50 2 0.01
# 0.0010039559642525087 100 50 2 0.01
# 0.0008313587564313747 150 50 2 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [4, 1, 2, 3], [12, 7, 3, 1], [4, 3, 3, 3], [6, 2, 2, 3]]
# library
# library
# library
# library
# library
# 0.6678918592029616 0 70 3 0.01
# 0.007568204516386419 50 70 3 0.01
# 0.0022939916658594644 100 70 3 0.01
# 0.0008918414884145079 150 70 3 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00110'] and ['00100']
# these are bitwise: ['00110', '00011'] and ['00100', '00001']
# these are bitwise: ['00110', '00011', '11'] and ['00100', '00001', '10']
# these are bitwise: ['00110', '00011', '11', '01'] and ['00100', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [4, 1, 2, 3], [4, 1, 3, 0], [12, 1, 2, 3]]
# library
# library
# library
# library
# 0.06063062526362553 0 50 2 0.001
# 0.0019811750380312756 50 50 2 0.001
# 0.0013223182926305015 100 50 2 0.001
# 0.0009691607980734808 150 50 2 0.001
# Done Training
# 1.4594132361504364 0 130 2 0.01
# 0.016941577110809465 50 130 2 0.01
# 0.05869839882425173 100 130 2 0.01
# 0.007835766698926432 150 130 2 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [4, 1, 2, 3], [16, 3, 3, 1], [15, 1, 1, 3]]
# library
# library
# library
# library
# 0.13448981324192466 0 170 4 0.001
# 0.004222860027921379 50 170 4 0.001
# 0.0008932473949178484 100 170 4 0.001
# 0.000849505513510343 150 170 4 0.001
# Done Training
# 1.0415185017493123 0 160 2 0.1
# 0.47022129348133346 50 160 2 0.1
# 0.03345161467269098 100 160 2 0.1
# 0.0025139740179784226 150 160 2 0.1
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [4, 1, 2, 3], [4, 3, 2, 1], [6, 9, 2, 3]]
# library
# library
# library
# library
# 0.27307974747763564 0 50 4 0.01
# 0.005164329212852569 50 50 4 0.01
# 0.0008437857146801917 100 50 4 0.01
# 0.0035607793508553734 150 50 4 0.01
# Done Training
# 0.11987304233214835 0 70 10 0.01
# 0.005223599101503557 50 70 10 0.01
# 0.0009992814132076177 100 70 10 0.01
# 0.0011238448246006366 150 70 10 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00001'] and ['00110', '00011']
# these are bitwise: ['00100', '00001', '11'] and ['00110', '00011', '10']
# these are bitwise: ['00100', '00001', '11', '01'] and ['00110', '00011', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [4, 1, 2, 3], [4, 3, 3, 1], [6, 11, 2, 1]]
# library
# library
# library
# library
# 0.14922822902605867 0 50 4 0.001
# 0.006538959492966976 50 50 4 0.001
# 0.0009650412008448757 100 50 4 0.001
# 0.0010412974512545579 150 50 4 0.001
# Done Training
# 0.15747838808460932 0 70 12 0.01
# 0.016743559572231084 50 70 12 0.01
# 0.0017818910215337098 100 70 12 0.01
# 0.0011393557543997327 150 70 12 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [4, 1, 2, 3], [4, 17, 3, 1], [6, 9, 2, 1]]
# library
# library
# library
# library
# library
# 0.07709079168911602 0 70 10 0.01
# 0.009324251719106436 50 70 10 0.01
# 0.0013979347178851907 100 70 10 0.01
# 0.0011408690709981209 150 70 10 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00110'] and ['00100']
# these are bitwise: ['00110', '00011'] and ['00100', '00001']
# these are bitwise: ['00110', '00011', '11'] and ['00100', '00001', '10']
# these are bitwise: ['00110', '00011', '11', '01'] and ['00100', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [4, 1, 2, 3], [6, 3, 1, 1], [4, 1, 2, 2]]
# library
# library
# library
# library
# 0.20524752196385665 0 70 4 0.1
# 0.17353174075762826 50 70 4 0.1
# 0.014943588911846077 100 70 4 0.1
# 0.0014853759015640239 150 70 4 0.1
# Done Training
# 0.4139099823135175 0 50 2 0.01
# 0.006063159674667039 50 50 2 0.01
# 0.0012300104925440356 100 50 2 0.01
# 0.0009604274335936665 150 50 2 0.01
# Done Training
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00001'] and ['00110', '00011']
# these are bitwise: ['00100', '00001', '11'] and ['00110', '00011', '10']
# these are bitwise: ['00100', '00001', '11', '01'] and ['00110', '00011', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [4, 1, 2, 3], [4, 1, 3, 3], [6, 3, 2, 3]]
# library
# library
# library
# library
# 0.059658352989590095 0 50 2 0.001
# 0.004019243444181497 50 50 2 0.001
# 0.001092323583327255 100 50 2 0.001
# 0.001077051992663194 150 50 2 0.001
# Done Training
# library
# this is the best: [6, 1, 2, 1]
# these are bitwise: ['00100'] and ['00110']
# these are bitwise: ['00100', '00011'] and ['00110', '00001']
# these are bitwise: ['00100', '00011', '11'] and ['00110', '00001', '10']
# these are bitwise: ['00100', '00011', '11', '01'] and ['00110', '00001', '10', '11']
# Current population is: [[6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [4, 1, 2, 3], [12, 17, 3, 0], [15, 1, 3, 3]]
# library
# library
# library
# library
# 0.10433409074184007 0 130 18 0.001
# 0.0012348276957564479 50 130 18 0.001
# 0.0011807726621138532 100 130 18 0.001
# 0.0011255997355806783 150 130 18 0.001
# Done Training
# 0.3155868167002334 0 160 2 0.001
# 0.006251647042565253 50 160 2 0.001
# 0.0013689646457951952 100 160 2 0.001
# 0.0006921858282375458 150 160 2 0.001
# Done Training
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01110'] and ['00111']
# these are bitwise: ['01110', '00001'] and ['00111', '00001']
# these are bitwise: ['01110', '00001', '10'] and ['00111', '00001', '11']
# these are bitwise: ['01110', '00001', '10', '11'] and ['00111', '00001', '11', '01']
# Current population is: [[15, 1, 3, 3], [6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [17, 1, 2, 3], [6, 9, 3, 1]]
# library
# library
# library
# library
# 1.7617915318975328 0 180 2 0.01
# 0.02802617265571423 50 180 2 0.01
# 0.004105149236856032 100 180 2 0.01
# 0.0011359333968449777 150 180 2 0.01
# Done Training
# 0.06612331390006868 0 70 10 0.001
# 0.0011648093010787936 50 70 10 0.001
# 0.0011583017155257147 100 70 10 0.001
# 0.0011262354835944442 150 70 10 0.001
# Done Training
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01110'] and ['00111']
# these are bitwise: ['01110', '00001'] and ['00111', '00001']
# these are bitwise: ['01110', '00001', '10'] and ['00111', '00001', '11']
# these are bitwise: ['01110', '00001', '10', '11'] and ['00111', '00001', '11', '01']
# Current population is: [[15, 1, 3, 3], [6, 1, 2, 1], [4, 3, 3, 3], [4, 3, 3, 3], [14, 0, 2, 3], [5, 1, 3, 0]]
# library
# library
# library
# library
# 2.601685856877996 0 150 1 0.01
# 0.046377418824995305 50 150 1 0.01
# 0.0033798347337650335 100 150 1 0.01
# 0.0009636453992534312 150 150 1 0.01
# Done Training
# 0.10738033683765487 0 60 2 0.001
# 0.0069377451693615755 50 60 2 0.001
# 0.0007568845629232736 100 60 2 0.001
# 0.0007641343266873016 150 60 2 0.001
# Done Training
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01101'] and ['00111']
# these are bitwise: ['01101', '00001'] and ['00111', '00001']
# these are bitwise: ['01101', '00001', '11'] and ['00111', '00001', '11']
# these are bitwise: ['01101', '00001', '11', '10'] and ['00111', '00001', '11', '01']
# Current population is: [[15, 1, 3, 3], [5, 1, 3, 0], [6, 1, 2, 1], [4, 3, 3, 3], [12, 1, 3, 2], [7, 1, 3, 3]]
# library
# library
# library
# library
# 0.19212066453136745 0 130 2 0.001
# 0.005031098940509318 50 130 2 0.001
# 0.0010485839128351678 100 130 2 0.001
# 0.0008467942877841459 150 130 2 0.001
# Done Training
# 0.03148872787914959 0 80 2 0.001
# 0.002257218810986779 50 80 2 0.001
# 0.0010524751518096707 100 80 2 0.001
# 0.0007312777470832583 150 80 2 0.001
# Done Training
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01111'] and ['00111']
# these are bitwise: ['01111', '00001'] and ['00111', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['00111', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['00111', '00001', '11', '11']
# Current population is: [[15, 1, 3, 3], [7, 1, 3, 3], [5, 1, 3, 0], [6, 1, 2, 1], [13, 1, 2, 1], [7, 1, 3, 3]]
# library
# library
# library
# library
# 1.6551893539147218 0 140 2 0.01
# 0.054340754552863225 50 140 2 0.01
# 0.0012237472163086078 100 140 2 0.01
# 0.0011184121939513346 150 140 2 0.01
# Done Training
# library
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01111'] and ['00111']
# these are bitwise: ['01111', '00001'] and ['00111', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['00111', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['00111', '00001', '11', '11']
# Current population is: [[15, 1, 3, 3], [7, 1, 3, 3], [7, 1, 3, 3], [5, 1, 3, 0], [13, 3, 3, 3], [17, 17, 3, 3]]
# library
# library
# library
# library
# 0.0793341537808234 0 140 4 0.001
# 0.0015136276456848416 50 140 4 0.001
# 0.00095376577343729 100 140 4 0.001
# 0.0009852717469291893 150 140 4 0.001
# Done Training
# 0.09254562616581404 0 180 18 0.001
# 0.0015520250105673773 50 180 18 0.001
# 0.0011274550029563278 100 180 18 0.001
# 0.0011305140050535784 150 180 18 0.001
# Done Training
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['00111'] and ['01111']
# these are bitwise: ['00111', '00001'] and ['01111', '00001']
# these are bitwise: ['00111', '00001', '11'] and ['01111', '00001', '11']
# these are bitwise: ['00111', '00001', '11', '11'] and ['01111', '00001', '11', '11']
# Current population is: [[15, 1, 3, 3], [7, 1, 3, 3], [7, 1, 3, 3], [5, 1, 3, 0], [2, 17, 2, 1], [17, 1, 3, 3]]
# library
# library
# library
# library
# 0.067901790581097 0 30 18 0.01
# 0.002246410412379435 50 30 18 0.01
# 0.0013413286282909775 100 30 18 0.01
# 0.0012554455709092897 150 30 18 0.01
# Done Training
# 0.4017790040465021 0 180 2 0.001
# 0.012803918666764818 50 180 2 0.001
# 0.0012379179664147898 100 180 2 0.001
# 0.000824053867842063 150 180 2 0.001
# Done Training
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01111'] and ['00111']
# these are bitwise: ['01111', '00001'] and ['00111', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['00111', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['00111', '00001', '11', '11']
# Current population is: [[15, 1, 3, 3], [7, 1, 3, 3], [7, 1, 3, 3], [5, 1, 3, 0], [15, 1, 3, 3], [7, 1, 3, 3]]
# library
# library
# library
# library
# library
# library
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01111'] and ['01111']
# these are bitwise: ['01111', '00001'] and ['01111', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['01111', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['01111', '00001', '11', '11']
# Current population is: [[15, 1, 3, 3], [15, 1, 3, 3], [7, 1, 3, 3], [7, 1, 3, 3], [5, 3, 3, 3], [11, 1, 3, 2]]
# library
# library
# library
# library
# 0.036988538556937574 0 60 4 0.001
# 0.002567203244286806 50 60 4 0.001
# 0.0009930801858698247 100 60 4 0.001
# 0.0008053247996725234 150 60 4 0.001
# Done Training
# 0.05719964284337255 0 120 2 0.001
# 0.007455032724694536 50 120 2 0.001
# 0.0015100256851929923 100 120 2 0.001
# 0.0009526177541639716 150 120 2 0.001
# Done Training
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01111'] and ['01111']
# these are bitwise: ['01111', '00001'] and ['01111', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['01111', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['01111', '00001', '11', '11']
# Current population is: [[15, 1, 3, 3], [15, 1, 3, 3], [7, 1, 3, 3], [7, 1, 3, 3], [12, 3, 3, 3], [15, 9, 3, 3]]
# library
# library
# library
# library
# 0.11387671732368597 0 130 4 0.001
# 0.0011354783803265876 50 130 4 0.001
# 0.00116234963493441 100 130 4 0.001
# 0.001032896200603266 150 130 4 0.001
# Done Training
# 0.04939032528595039 0 160 10 0.001
# 0.002051492876189788 50 160 10 0.001
# 0.001120386298801719 100 160 10 0.001
# 0.0009842313201215546 150 160 10 0.001
# Done Training
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01111'] and ['01111']
# these are bitwise: ['01111', '00001'] and ['01111', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['01111', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['01111', '00001', '11', '11']
# Current population is: [[15, 1, 3, 3], [15, 1, 3, 3], [7, 1, 3, 3], [7, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3]]
# library
# library
# library
# library
# library
# library
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01111'] and ['01111']
# these are bitwise: ['01111', '00001'] and ['01111', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['01111', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['01111', '00001', '11', '11']
# Current population is: [[15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 1]]
# library
# library
# library
# library
# library
# 0.2853242804735389 0 160 2 0.001
# 0.00881406334545334 50 160 2 0.001
# 0.0009607540510258664 100 160 2 0.001
# 0.0010237625140689093 150 160 2 0.001
# Done Training
# this is the best: [15, 1, 3, 3]
# these are bitwise: ['01111'] and ['01111']
# these are bitwise: ['01111', '00001'] and ['01111', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['01111', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['01111', '00001', '11', '11']
# Current population is: [[15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [7, 5, 3, 2], [14, 1, 3, 3]]
# library
# library
# library
# library
# 0.03226939414205159 0 80 6 0.001
# 0.0013717115979669863 50 80 6 0.001
# 0.0011496720560694048 100 80 6 0.001
# 0.0010254693175328327 150 80 6 0.001
# Done Training
# 0.19182698517337302 0 150 2 0.001
# 0.004189636397871932 50 150 2 0.001
# 0.0009035445769391933 100 150 2 0.001
# 0.000633750788298688 150 150 2 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01111'] and ['01110']
# these are bitwise: ['01111', '00001'] and ['01110', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 9, 3, 3], [6, 9, 1, 1]]
# library
# library
# library
# library
# library
# 1.7369920084090347 0 70 10 0.1
# 0.24313768782806197 50 70 10 0.1
# 0.030158140858789328 100 70 10 0.1
# 0.0020028459768530026 150 70 10 0.1
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01111'] and ['01110']
# these are bitwise: ['01111', '00001'] and ['01110', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 3, 3, 3], [17, 3, 3, 1]]
# library
# library
# library
# library
# 0.10127268965637272 0 160 4 0.001
# 0.0037497213438122184 50 160 4 0.001
# 0.0011341084024310815 100 160 4 0.001
# 0.0010103352960266379 150 160 4 0.001
# Done Training
# 0.217086997895589 0 180 4 0.001
# 0.0012602164440618363 50 180 4 0.001
# 0.001100495793752656 100 180 4 0.001
# 0.0009339925889050782 150 180 4 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01111'] and ['01110']
# these are bitwise: ['01111', '00001'] and ['01110', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [14, 1, 1, 3], [14, 3, 3, 3]]
# library
# library
# library
# library
# 1.5250729315122002 0 150 2 0.1
# 0.7404244471399446 50 150 2 0.1
# 0.061093217240906515 100 150 2 0.1
# 0.0039296943209191386 150 150 2 0.1
# Done Training
# 0.21026738881246834 0 150 4 0.001
# 0.002492086333305657 50 150 4 0.001
# 0.0009035134794969201 100 150 4 0.001
# 0.0009067091333400382 150 150 4 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01111'] and ['01110']
# these are bitwise: ['01111', '00001'] and ['01110', '00001']
# these are bitwise: ['01111', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01111', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [17, 17, 1, 2], [14, 1, 3, 3]]
# library
# library
# library
# library
# 1.2502070515142865 0 180 18 0.1
# 1.6097881044886078 50 180 18 0.1
# 0.11281647078052236 100 180 18 0.1
# 0.009039675206235468 150 180 18 0.1
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [17, 1, 3, 1], [15, 1, 3, 3]]
# library
# library
# library
# library
# 0.34836976577150014 0 180 2 0.001
# 0.0063756029984449215 50 180 2 0.001
# 0.0008944373387584628 100 180 2 0.001
# 0.001155954027881032 150 180 2 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [15, 1, 3, 3], [15, 1, 3, 3], [14, 1, 3, 3], [17, 1, 3, 2]]
# library
# library
# library
# library
# library
# 0.3977410610419733 0 180 2 0.001
# 0.00751887852967828 50 180 2 0.001
# 0.0019992169783840815 100 180 2 0.001
# 0.0010018824309620655 150 180 2 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [15, 1, 3, 3], [14, 5, 3, 3], [14, 1, 3, 3]]
# library
# library
# library
# library
# 0.04947547467864272 0 150 6 0.001
# 0.0010590308143691898 50 150 6 0.001
# 0.0010706411318151274 100 150 6 0.001
# 0.0008668872241004149 150 150 6 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3]]
# library
# library
# library
# library
# library
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 17, 3, 3], [14, 0, 2, 3]]
# library
# library
# library
# library
# 0.04499314876847108 0 150 18 0.001
# 0.0013220345562493232 50 150 18 0.001
# 0.001133591979920425 100 150 18 0.001
# 0.0010168575174921244 150 150 18 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 1, 3], [14, 3, 3, 2]]
# library
# library
# library
# library
# library
# 0.06235353389721396 0 150 4 0.001
# 0.00548067107050605 50 150 4 0.001
# 0.000958320904486822 100 150 4 0.001
# 0.0008339628225125832 150 150 4 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 17, 3, 2], [15, 3, 3, 3]]
# library
# library
# library
# library
# 0.07706124505077637 0 150 18 0.001
# 0.0014100570931401928 50 150 18 0.001
# 0.0011361294997356691 100 150 18 0.001
# 0.001135340235956846 150 150 18 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 0, 2, 3], [14, 9, 1, 3]]
# library
# library
# library
# library
# library
# 3.3859596521682125 0 150 10 0.1
# 0.8154757981149574 50 150 10 0.1
# 0.05749269105418843 100 150 10 0.1
# 0.0043009185404737455 150 150 10 0.1
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [10, 9, 3, 3], [17, 1, 3, 2]]
# library
# library
# library
# library
# 0.042606033927156284 0 110 10 0.001
# 0.0013103873729980822 50 110 10 0.001
# 0.0011318985515819029 100 110 10 0.001
# 0.0010284640664085032 150 110 10 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 9, 3, 3]]
# library
# library
# library
# library
# library
# 0.016661280512329187 0 150 10 0.001
# 0.0019108172274160558 50 150 10 0.001
# 0.0011394876025250607 100 150 10 0.001
# 0.0028778044193780495 150 150 10 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 16, 3, 3], [12, 1, 3, 3]]
# library
# library
# library
# library
# 0.04773449800370265 0 150 17 0.001
# 0.0017189783707030563 50 150 17 0.001
# 0.001134197987105414 100 150 17 0.001
# 0.0011316165871365982 150 150 17 0.001
# Done Training
# 0.18827217511287964 0 130 2 0.001
# 0.004536667079564648 50 130 2 0.001
# 0.0007752788532983919 100 130 2 0.001
# 0.0006560977862887502 150 130 2 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [12, 3, 3, 3], [14, 1, 3, 3]]
# library
# library
# library
# library
# library
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 0, 3, 1]]
# library
# library
# library
# library
# library
# 0.15676978225924004 0 150 1 0.001
# 0.007958455879131163 50 150 1 0.001
# 0.001226343249735167 100 150 1 0.001
# 0.0011517831197346143 150 150 1 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [17, 1, 3, 3], [14, 1, 2, 3]]
# library
# library
# library
# library
# library
# 1.800636854026392 0 150 2 0.01
# 0.0428305661737808 50 150 2 0.01
# 0.004177057270430383 100 150 2 0.01
# 0.0012628991369624824 150 150 2 0.01
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [10, 17, 3, 1], [14, 1, 3, 3]]
# library
# library
# library
# library
# 0.09174180484395672 0 110 18 0.001
# 0.0023457876648252914 50 110 18 0.001
# 0.0010749955682068481 100 110 18 0.001
# 0.0011416175598866782 150 110 18 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [17, 1, 3, 2]]
# library
# library
# library
# library
# library
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 0, 1, 3], [6, 5, 3, 2]]
# library
# library
# library
# library
# 3.12144286401727 0 150 1 0.1
# 0.3119716038895232 50 150 1 0.1
# 0.030391653552262938 100 150 1 0.1
# 0.002478118611640035 150 150 1 0.1
# Done Training
# 0.029241590879013048 0 70 6 0.001
# 0.002000235625102348 50 70 6 0.001
# 0.0010396465769521859 100 70 6 0.001
# 0.0008199057036283877 150 70 6 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 1, 2]]
# library
# library
# library
# library
# library
# 1.9848031741583212 0 150 2 0.1
# 0.6392242698214867 50 150 2 0.1
# 0.04089573492311029 100 150 2 0.1
# 0.003918602647942882 150 150 2 0.1
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3]]
# library
# library
# library
# library
# library
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 9, 2, 3]]
# library
# library
# library
# library
# library
# 0.3780235598763183 0 150 10 0.01
# 0.02718173049338368 50 150 10 0.01
# 0.007024668778645938 100 150 10 0.01
# 0.0025684986681255174 150 150 10 0.01
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 0, 3, 3]]
# library
# library
# library
# library
# library
# 0.12979263764221108 0 150 1 0.001
# 0.009468224486935212 50 150 1 0.001
# 0.0017335221856633915 100 150 1 0.001
# 0.0009318644011553938 150 150 1 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 2]]
# library
# library
# library
# library
# library
# 0.15715083449065376 0 150 2 0.001
# 0.008106270285052597 50 150 2 0.001
# 0.0011915730585092415 100 150 2 0.001
# 0.0007492510284247028 150 150 2 0.001
# Done Training
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [6, 13, 3, 3], [14, 1, 3, 3]]
# library
# library
# library
# library
# 0.06370013879082821 0 70 14 0.001
# 0.0011429372519180397 50 70 14 0.001
# 0.0011355415636930138 100 70 14 0.001
# 0.0011342730436118829 150 70 14 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [12, 5, 1, 3], [15, 1, 3, 3]]
# library
# library
# library
# library
# 0.7185195797562256 0 130 6 0.1
# 0.33520974334213566 50 130 6 0.1
# 0.024251611772180996 100 130 6 0.1
# 0.001201715001723553 150 130 6 0.1
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 17, 3, 2], [14, 1, 1, 3]]
# library
# library
# library
# library
# library
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [10, 7, 3, 3], [15, 1, 3, 3]]
# library
# library
# library
# library
# 0.03347715133034943 0 110 8 0.001
# 0.000919020165998369 50 110 8 0.001
# 0.001046900146248512 100 110 8 0.001
# 0.0026703775350310644 150 110 8 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [17, 11, 3, 2], [14, 1, 2, 3]]
# library
# library
# library
# library
# 0.08101109521259775 0 180 12 0.001
# 0.001779071909278134 50 180 12 0.001
# 0.001141496257254372 100 180 12 0.001
# 0.0010687380436717043 150 180 12 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [12, 17, 3, 3], [14, 1, 3, 3]]
# library
# library
# library
# library
# 0.035310300061539485 0 130 18 0.001
# 0.0015435875290428307 50 130 18 0.001
# 0.001184001172043251 100 130 18 0.001
# 0.0010815668614240117 150 130 18 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [17, 9, 3, 3], [14, 9, 3, 3]]
# library
# library
# library
# library
# 0.07115439008438627 0 180 10 0.001
# 0.0028089880007229695 50 180 10 0.001
# 0.001232661285492079 100 180 10 0.001
# 0.0011252510798537123 150 180 10 0.001
# Done Training
# library
# this is the best: [14, 1, 3, 3]
# these are bitwise: ['01110'] and ['01110']
# these are bitwise: ['01110', '00001'] and ['01110', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '11'] and ['01110', '00001', '11', '11']
# Current population is: [[14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [10, 1, 3, 1], [12, 1, 3, 3]]
# library
# library
# library
# library
# 0.12353623061321932 0 110 2 0.001
# 0.005720133778775351 50 110 2 0.001
# 0.0009095521569933012 100 110 2 0.001
# 0.000625787299777823 150 110 2 0.001
# Done Training
# library
# this is the best: [10, 1, 3, 1]
# these are bitwise: ['01010'] and ['01110']
# these are bitwise: ['01010', '00001'] and ['01110', '00001']
# these are bitwise: ['01010', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01010', '00001', '11', '01'] and ['01110', '00001', '11', '11']
# Current population is: [[10, 1, 3, 1], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [10, 17, 3, 1], [6, 1, 3, 3]]
# library
# library
# library
# library
# library
# 0.13893285495564417 0 70 2 0.001
# 0.009517754114489078 50 70 2 0.001
# 0.0007722131438841635 100 70 2 0.001
# 0.0009676867971932435 150 70 2 0.001
# Done Training
# this is the best: [10, 1, 3, 1]
# these are bitwise: ['01110'] and ['01010']
# these are bitwise: ['01110', '00001'] and ['01010', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01010', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '01'] and ['01010', '00001', '11', '11']
# Current population is: [[10, 1, 3, 1], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 1], [8, 1, 3, 3]]
# library
# library
# library
# library
# 0.15276931547834288 0 150 2 0.001
# 0.006441398145998629 50 150 2 0.001
# 0.0007516824186553963 100 150 2 0.001
# 0.0007330299991821501 150 150 2 0.001
# Done Training
# 0.05651458723196291 0 90 2 0.001
# 0.00878047126368853 50 90 2 0.001
# 0.0014825753656364077 100 90 2 0.001
# 0.001320080044883289 150 90 2 0.001
# Done Training
# this is the best: [10, 1, 3, 1]
# these are bitwise: ['01110'] and ['01010']
# these are bitwise: ['01110', '00001'] and ['01010', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01010', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '01'] and ['01010', '00001', '11', '11']
# Current population is: [[10, 1, 3, 1], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 3, 3, 1], [10, 1, 3, 2]]
# library
# library
# library
# library
# 0.15538053236412444 0 150 4 0.001
# 0.005444191305061782 50 150 4 0.001
# 0.0009274906472473978 100 150 4 0.001
# 0.000784697269611474 150 150 4 0.001
# Done Training
# 0.09417726626294341 0 110 2 0.001
# 0.00465061680355698 50 110 2 0.001
# 0.0011819719677840094 100 110 2 0.001
# 0.0008016508579424706 150 110 2 0.001
# Done Training
# this is the best: [10, 1, 3, 1]
# these are bitwise: ['01010'] and ['01110']
# these are bitwise: ['01010', '00001'] and ['01110', '00001']
# these are bitwise: ['01010', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01010', '00001', '11', '01'] and ['01110', '00001', '11', '11']
# Current population is: [[10, 1, 3, 1], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [10, 1, 1, 1], [14, 1, 3, 3]]
# library
# library
# library
# library
# 2.21470609402797 0 110 2 0.1
# 0.8086467187436035 50 110 2 0.1
# 0.02800408248817903 100 110 2 0.1
# 0.005085223614135721 150 110 2 0.1
# Done Training
# library
# this is the best: [10, 1, 3, 1]
# these are bitwise: ['01110'] and ['01010']
# these are bitwise: ['01110', '00001'] and ['01010', '00001']
# these are bitwise: ['01110', '00001', '11'] and ['01010', '00001', '11']
# these are bitwise: ['01110', '00001', '11', '01'] and ['01010', '00001', '11', '11']
# Current population is: [[10, 1, 3, 1], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 1], [8, 1, 3, 3]]
# library
# library
# library
# library
# library
# library
# this is the best: [10, 1, 3, 1]
# these are bitwise: ['01010'] and ['01110']
# these are bitwise: ['01010', '00001'] and ['01110', '00001']
# these are bitwise: ['01010', '00001', '11'] and ['01110', '00001', '11']
# these are bitwise: ['01010', '00001', '11', '01'] and ['01110', '00001', '11', '11']
# Current population is: [[10, 1, 3, 1], [14, 1, 3, 3], [14, 1, 3, 3], [14, 1, 3, 3], [10, 3, 3, 3], [14, 1, 3, 0]]
# library
# library
# library
# library
# 0.044143904416425774 0 110 4 0.001
# ...
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [10, 1, 3, 1], [11, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [17, 1, 2, 1], [11, 0, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 0], [11, 5, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 0, 3, 1], [2, 3, 2, 1]]
# library
# library
# library
# library
# library
# 0.20945125098027456 0 30 4 0.01
# 0.004462861549090805 50 30 4 0.01
# 0.0010408110653804023 100 30 4 0.01
# 0.0008928532621470068 150 30 4 0.01
# Done Training
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 3]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [17, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 17, 3, 3], [11, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 3], [15, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 9, 2, 1], [11, 1, 3, 0]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 3], [17, 9, 2, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [15, 0, 3, 3], [11, 1, 3, 1]]
# library
# library
# library
# library
# 0.1562965157243925 0 160 1 0.001
# 0.012260963669795408 50 160 1 0.001
# 0.0016536541240070389 100 160 1 0.001
# 0.0006478034747603234 150 160 1 0.001
# Done Training
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [14, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [10, 1, 3, 1], [17, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 8, 3, 1], [11, 1, 1, 2]]
# library
# library
# library
# library
# library
# 2.100746540561931 0 120 2 0.1
# 0.6374369890216962 50 120 2 0.1
# 0.023342043172918218 100 120 2 0.1
# 0.004231745261593638 150 120 2 0.1
# Done Training
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 4, 3, 3], [11, 1, 3, 1]]
# library
# library
# library
# library
# 0.05571984782860801 0 120 5 0.001
# 0.0031469395900419425 50 120 5 0.001
# 0.0010413102221666544 100 120 5 0.001
# 0.0009673599630715828 150 120 5 0.001
# Done Training
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 2, 3, 1], [10, 0, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [3, 1, 3, 1], [3, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [17, 17, 3, 1], [3, 5, 2, 1]]
# library
# library
# library
# library
# library
# 0.05664030446637552 0 40 6 0.01
# 0.0032974954881539714 50 40 6 0.01
# 0.001139224348557938 100 40 6 0.01
# 0.0011220984137535611 150 40 6 0.01
# Done Training
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [9, 9, 3, 1], [17, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [8, 1, 3, 1], [11, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 2, 1], [11, 1, 3, 1]]
# library
# library
# library
# library
# library
# library
# this is the best: [11, 1, 3, 1]
# these are bitwise: ['01011'] and ['01011']
# these are bitwise: ['01011', '00001'] and ['01011', '00001']
# these are bitwise: ['01011', '00001', '11'] and ['01011', '00001', '11']
# these are bitwise: ['01011', '00001', '11', '01'] and ['01011', '00001', '11', '01']
# Current population is: [[11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 1, 3, 1], [11, 17, 3, 0]]
# library
# library
# library
# library
# library
# 0.05972022985792866 0 120 18 0.001
# 0.0011631427245726294 50 120 18 0.001
# 0.0011413828369225682 100 120 18 0.001
# 0.0011291778628217575 150 120 18 0.001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1e977436ae17> in <module>
#       7     if (any(j == 'neural_network' for j in config['config'])):
#       8         optimizer = GeneticAlgorithm(config,coordinates,  output,val_coordinates, val_output)
# ----> 9         optimizer.run()
#      10
#      11
#
# ~/projects/MachineLearningNew/MachineLearningScanner-2/GeneticAlgorithm.py in run(self)
#     139
#     140         for i in range(self.iterations):
# --> 141             orderedpop=self.getOrder(population)
#     142             print(f'this is the best: {orderedpop[0]}')
#     143             population=self.newGeneration(orderedpop)
#
# ~/projects/MachineLearningNew/MachineLearningScanner-2/GeneticAlgorithm.py in getOrder(self, population)
#      79
#      80     def getOrder(self,population):
# ---> 81         populationscore = self.getScore(population)
#      82         orderedpop = [pop for _, pop in sorted(zip(populationscore, population))]
#      83         return orderedpop
#
# ~/projects/MachineLearningNew/MachineLearningScanner-2/GeneticAlgorithm.py in getScore(self, population)
#      85     def getScore(self,population):
#      86         print(f'Current population is: {population}')
# ---> 87         score = [self.callCE(pop) for pop in population]
#      88         return score
#      89
#
# ~/projects/MachineLearningNew/MachineLearningScanner-2/GeneticAlgorithm.py in <listcomp>(.0)
#      85     def getScore(self,population):
#      86         print(f'Current population is: {population}')
# ---> 87         score = [self.callCE(pop) for pop in population]
#      88         return score
#      89
#
# ~/projects/MachineLearningNew/MachineLearningScanner-2/GeneticAlgorithm.py in callCE(self, positionlist)
#      57             print("library")
#      58         else:
# ---> 59             error = self.getNewNetwork(positionlist)
#      60             self.searchlog[str(positionlist)] = error
#      61         return error
#
# ~/projects/MachineLearningNew/MachineLearningScanner-2/GeneticAlgorithm.py in getNewNetwork(self, positions)
#      65                                                     hiddenlayer_size= self.nodes[positions[0]], hiddenlayer_number = self.layers[positions[1]],
#      66                                                     learning_rate=self.learningrate[positions[2]],batch_size=self.batchsize[positions[3]])
# ---> 67         error = network.train()
#      68         return error
#      69
#
# ~/projects/MachineLearningNew/MachineLearningScanner-2/NeuralNetwork.py in train(self)
#     112                 # Calling the step function on an Optimizer makes an update to its
#     113                 # parameters
# --> 114                 self.optimizer.step()
#     115
#     116
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py in step(self, closure)
#     131                     state_steps.append(state['step'])
#     132
# --> 133             F.adam(params_with_grad,
#     134                    grads,
#     135                    exp_avgs,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      92             denom = (max_exp_avg_sqs[i].sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      93         else:
# ---> 94             denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      95
#      96         step_size = lr / bias_correction1
#
# KeyboardInterrupt:
